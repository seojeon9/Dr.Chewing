# %%
# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm_notebook
import urllib
from urllib.request import urlopen
import re

# %%
df = pd.read_csv("./datas/서울시 착한가격음식점(메뉴가격나열).csv",encoding='cp949',index_col=0)
df.head(2)
df.columns
# Out:
# Index(['업소명', '분류코드', '분류코드명', '업소 주소', '업소 전화번호', '찾아오시는 길', '업소정보', '자랑거리',
#        '추천수', '기준년월', '업소 사진', '위도', '경도', '행정구', '행정동', '검색명', '식당아이디', '별점',
#        '상품명', '상품가격(일반)(원)'],
#       dtype='object')

# %%
df = pd.read_csv("./datas/서대문구 표본(메뉴가격 추가).csv",encoding='cp949',index_col=0)
df.head(2)
df.columns
# Out:
# Index(['상세영업상태명', '전화번호', '소재지면적', '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호',
#        '사업장명', '최종수정일자', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)',
#        '위생업태명', '검색명', '업소URL', '대표메뉴', '가격정보'],
#       dtype='object')

# %%
len(df)
# Out:
# 338

# %%
prc = pd.read_excel("./datas/외식비(22년 7월)(한국소비자원).xls")
prc.iloc[[0]]
# Out:
#    번호  지역     냉면   비빔밥  김치찌개백반  삼겹살(환산전)  삼겹살(환산후)   자장면    삼계탕   칼국수    김밥
# 0   1  서울  10423  9654    7423     15231     18056  6300  15385  8385  2969

# %%
df1 = df[df['대표메뉴'].str.contains('삼겹살') ==True]
df1['메뉴라벨링'] = '삼겹살'
df1['외식비'] = '18056'

df2 = df[df['대표메뉴'].str.contains('냉면') ==True]
df2['메뉴라벨링'] = '냉면'
df2['외식비'] = '10423'

df3 = df[df['대표메뉴'].str.contains('비빔밥') ==True]
df3['메뉴라벨링'] = '비빔밥'
df3['외식비'] = '9654'

df4 = df[df['대표메뉴'].str.contains('김치찌개') ==True]
df4['메뉴라벨링'] = '김치찌개백반'
df4['외식비'] = '7423'

df5 = df[df['대표메뉴'].str.contains('자장면') ==True]
df5['메뉴라벨링'] = '자장면'
df5['외식비'] = '6300'

df6 = df[df['대표메뉴'].str.contains('짜장면') ==True]
df6['메뉴라벨링'] = '자장면'
df6['외식비'] = '6300'

df7 = df[df['대표메뉴'].str.contains('삼계탕') ==True]
df7['메뉴라벨링'] = '삼계탕'
df7['외식비'] = '15385'


df8 = df[df['대표메뉴'].str.contains('칼국수') ==True]
df8['메뉴라벨링'] = '칼국수'
df8['외식비'] = '8385'


df9 = df[df['대표메뉴'].str.contains('김밥') ==True]
df9['메뉴라벨링'] = '김밥'
df9['외식비'] = '2969'
# Out:
# <ipython-input-56-5f65f80c9f18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['메뉴라벨링'] = '삼겹살'
# <ipython-input-56-5f65f80c9f18>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['외식비'] = '18056'
# <ipython-input-56-5f65f80c9f18>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_list = [df1,df2,df3,df4,df5,df6,df7,df8,df9]

# %%
# 노가다 전
# print("삼겹살 : ",len(df1))
# print("냉면 : ",len(df2))
# print("비빔밥 : ",len(df3))
# print("김치찌개 : ",len(df4))
# print("자장면 : ",len(df5))
# print("짜장면 : ",len(df6))
# print("삼계탕 : ",len(df7))
# print("칼국수 : ",len(df8))
# print("김밥 : ",len(df9))
# Out:
# 삼겹살 :  7
# 냉면 :  2
# 비빔밥 :  3
# 김치찌개 :  1
# 자장면 :  1
# 짜장면 :  3
# 삼계탕 :  0
# 칼국수 :  4
# 김밥 :  6

# %%
# 노가다 후
print("삼겹살 : ",len(df1))
print("냉면 : ",len(df2))
print("비빔밥 : ",len(df3))
print("김치찌개 : ",len(df4))
print("자장면 : ",len(df5))
print("짜장면 : ",len(df6))
print("삼계탕 : ",len(df7))
print("칼국수 : ",len(df8))
print("김밥 : ",len(df9))
# Out:
# 삼겹살 :  11
# 냉면 :  2
# 비빔밥 :  3
# 김치찌개 :  3
# 자장면 :  1
# 짜장면 :  3
# 삼계탕 :  1
# 칼국수 :  5
# 김밥 :  6

# %%
df_all = pd.concat(df_list, ignore_index=True)
df_all
# Out:
#    상세영업상태명          전화번호   소재지면적  소재지우편번호  \
# 0       영업    02 3639289   98.04   120809
# 1       영업           NaN   66.00   120857
# 2       영업    02 3960213   51.00   120857
# 3       영업  02  337 8203   42.39   120827
# 4       영업           NaN   56.53   120100
# 5       영업  02  303 2191   49.50   120800
# 6       영업  02  392 9993  145.00   120833
# 7       영업  02  337 9229  203.49   120834
# 8       영업           NaN   44.65   120050
# 9       영업  02  309 3446   53.82   120806
# 10      영업           NaN   40.90   120857
# 11      영업           NaN   63.84   120863
# 12      영업           NaN   40.00   120854
# 13      영업    02 3121212   18.09   120030
# 14      영업    02 3628684   77.28   120160
# 15      영업           NaN   89.00   120808
# 16      영업           NaN   52.80   120716
# 17      영업    02 3378515   24.40   120834
# 18      영업  02  336 7278   54.00   120834
# 19      영업    02 3229998  225.65   120825
# 20      영업           NaN   70.20   120819
# ...

# %%
len(df_all)
# Out:
# 35

# %%
df_all = df_all.sort_index()

# %%
df_all
# Out:
#    상세영업상태명          전화번호   소재지면적  소재지우편번호  \
# 0       영업    02 3639289   98.04   120809
# 1       영업           NaN   66.00   120857
# 2       영업    02 3960213   51.00   120857
# 3       영업  02  337 8203   42.39   120827
# 4       영업           NaN   56.53   120100
# 5       영업  02  303 2191   49.50   120800
# 6       영업  02  392 9993  145.00   120833
# 7       영업  02  337 9229  203.49   120834
# 8       영업           NaN   44.65   120050
# 9       영업  02  309 3446   53.82   120806
# 10      영업           NaN   40.90   120857
# 11      영업           NaN   63.84   120863
# 12      영업           NaN   40.00   120854
# 13      영업    02 3121212   18.09   120030
# 14      영업    02 3628684   77.28   120160
# 15      영업           NaN   89.00   120808
# 16      영업           NaN   52.80   120716
# 17      영업    02 3378515   24.40   120834
# 18      영업  02  336 7278   54.00   120834
# 19      영업    02 3229998  225.65   120825
# 20      영업           NaN   70.20   120819
# ...

# %%
df_all.to_csv('./datas/서대문구 표본(라벨링).csv',encoding='cp949')

# %% [markdown]
# ### 수동으로 채워주기 프로젝트..

# %%
df_url = df[df['업소URL'] != '-']
df_menu = df_url[df['대표메뉴'] == '-']
len(df_menu)
df_menu[['사업장명','검색명','업소URL']]
# Out:
# <ipython-input-19-d2c6560ed6e9>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_menu = df_url[df['대표메뉴'] == '-']
#             사업장명                   검색명       업소URL
# 0          식도락식당       서대문구 북가좌동 식도락식당  1322958809
# 11            가을           서대문구 연희동 가을   618180525
# 21          진주식당       서대문구 충정로3가 진주식당  1236770208
# 22       도깨비 칼국수      서대문구 영천동 도깨비 칼국수  1270012818
# 27          연희식당         서대문구 연희동 연희식당  1726545875
# 28          와글바글         서대문구 홍은동 와글바글  1075382616
# 33       옥이네 왕돈가      서대문구 홍은동 옥이네 왕돈가    18752557
# 40           술찾사         서대문구 남가좌동 술찾사    18277898
# 44           모퉁이          서대문구 홍제동 모퉁이  1448256711
# 46          청춘보쌈        서대문구 남가좌동 청춘보쌈  1326644451
# 50           홍식당          서대문구 홍은동 홍식당  1148644917
# 52        한우본가갈비       서대문구 홍은동 한우본가갈비    18754065
# 56       식껍 홍제역점      서대문구 홍제동 식껍 홍제역점  1839639019
# 58           사랑채          서대문구 홍은동 사랑채    51425868
# ...

# %%
# 21, 22, 27, 50, 56, 75, 110, 111,|| 188 ,193, 217, 247, 287, 307
df['대표메뉴'][111] = df_menu['대표메뉴'][111]
df['가격정보'][111] = df_menu['가격정보'][111]
# Out:
# <ipython-input-47-dcc07bc3db47>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['대표메뉴'][111] = df_menu['대표메뉴'][111]
# <ipython-input-47-dcc07bc3db47>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['가격정보'][111] = df_menu['가격정보'][111]

# %%
len(df)
# Out:
# 338

# %%
df.loc[32]
# Out:
# 상세영업상태명                                 영업
# 전화번호                          02  394 3919
# 소재지면적                               241.05
# 소재지우편번호                             120100
# 지번주소         서울특별시 서대문구 홍은동 48-149번지 1~2층
# 도로명주소      서울특별시 서대문구 세검정로1길 21 1~2층 (홍은동)
# 도로명우편번호                             3615.0
# 사업장명                   산천마루 누룽지백숙 삼계탕 간장게장
# 최종수정일자                    20180600000000.0
# 데이터갱신구분                                  I
# 데이터갱신일자                            59:59.0
# 업태구분명                                   한식
# 좌표정보(X)                        194882.6446
# 좌표정보(Y)                        454472.6309
# 위생업태명                                   한식
# 검색명           서대문구 홍은동 산천마루 누룽지백숙 삼계탕 간장게장
# 업소URL                             34745133
# 대표메뉴                                 한방삼계탕
# 가격정보                                 15000
# Name: 32, dtype: object

# %%
df['업소URL'][32] = '34745133'
df['대표메뉴'][32] = '한방삼계탕'
df['가격정보'][32] = 15000
# Out:
# <ipython-input-54-2e3c418631bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['업소URL'][32] = '34745133'
# <ipython-input-54-2e3c418631bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['대표메뉴'][32] = '한방삼계탕'
# <ipython-input-54-2e3c418631bb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['가격정보'][32] = 15000
